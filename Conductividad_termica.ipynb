# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import ColumnDataSource

output_notebook()
# Crear datos de ejemplo
x = [103.14, 110.98, 134.51, 139.22, 140.78, 147.06, 154.9,  172.16, 176.86, 178.43,
 181.57, 192.55, 211.37, 212.94, 216.08 ,217.65, 227.06, 263.14, 264.71, 266.27,
 285.1,  314.9 , 321.18, 322.75, 343.14, 358.82, 363.53, 398.04, 399.61]

Aluminio = [453.59, 447.65, 433.48, 431.75, 431.26, 429.66, 428.36, 427.3,  427.27 ,427.28,
 427.31, 427.63, 428.84, 429.01, 429.4,  429.64, 430.39, 430.41, 430.39, 430.37,
 428.84, 423.96, 422.92, 422.66, 419.27, 416.72, 415.99, 467.28, 471.39]

Oro = [469.06, 468.92, 468.01, 467.65, 467.52, 466.86, 465.87, 463.59, 463.04, 462.88,
 462.55, 461.56, 460.19, 460.08, 459.88, 459.78, 459.78, 459.82, 459.8,  459.78,
 458.23, 454.53, 453.78, 453.59, 451.14, 449.17, 448.5, 478.87, 481.41]

Tungsteno = [427.3,  426.22, 422.43, 421.46, 421.11, 419.59, 417.41, 411.88, 410.28, 409.75,
 408.68, 404.92, 398.45, 397.91, 396.83, 396.3,  393.27, 380.89, 380.26, 379.61,
 371.61, 363.98, 362.33, 361.9,  355.9,  351.25, 349.95, 342.51, 342.22]

Hierro = [357.46, 354.59, 345.81, 343.94, 343.3,  340.67, 337.22, 329.35, 327.23, 326.55,
 325.2,  320.8,  312.14, 311.35, 309.73, 308.92, 303.91, 283.81, 282.92, 282.02,
 271.06, 250.95, 246.02, 244.75, 224.66, 201.54, 198.36, 204.55, 205.13]

Platino = [305.09, 304.03, 300.98, 300.45, 300.29, 299.77, 298.91, 296.62, 296.32, 296.24,
 296.1,  295.81, 295.76, 295.78, 295.8,  295.82, 295.93, 296.7,  296.74, 296.79,
 297.36, 299.21, 300.19, 300.45, 303.95, 306.64, 308.19, 318.56, 319.02]

Plata = [499.01, 488.76, 488.37, 477.8,  476.89, 474.77, 474.76, 471.12, 467.0,   466.66,
 466.63, 464.3,  464.26, 457.03, 455.26, 454.92, 449.56, 449.52, 449.35, 436.46,
 435.56, 435.53, 422.48, 420.33, 420.29]

Acero_inoxidable = [155.0, 161.54, 161.72, 164.7,  164.93, 165.98, 165.99, 167.3,  167.79, 167.86,
 167.86, 168.14, 168.15, 170.39, 170.99, 171.1,  172.69, 172.7, 172.74, 176.97,
 177.3,  177.31, 182.44, 183.3, 183.31]

Cobre = [449.68, 452.7, 474.31, 473.46, 469.77, 469.75, 464.8, 459.59, 459.15,
 459.11, 456.78, 456.75, 449.56, 447.76, 447.4, 442.03, 441.99, 441.84, 430.13,
 429.29, 429.26, 416.27, 414.06, 414.01]

# Crear un objeto ColumnDataSource para los datos
source = ColumnDataSource(data=dict(x=x, Aluminio=Aluminio, Oro=Oro,Tungsteno=Tungsteno, Hierro=Hierro, Platino=Platino, Plata=Plata,
                                   Acero_inoxidable= Acero_inoxidable,Cobre=Cobre))

# Crear una figura con título y etiquetas de ejes
p = figure(title="Dos líneas", x_axis_label='Temperatura(k)', y_axis_label='(W/m.k)')

# Añadir las líneas a la figura
p.line('x', 'Aluminio', source=source, line_color='blue', line_width=2, legend_label='Aluminio')
p.line('x', 'Oro', source=source, line_color='red', line_width=2, legend_label='Oro')
p.line('x', 'Tungsteno', source=source, line_color='pink', line_width=2, legend_label='Tungsteno')
p.line('x', 'Hierro', source=source, line_color='green', line_width=2, legend_label='Hierro')
p.line('x', 'Platino', source=source, line_color='gray', line_width=2, legend_label='Platino')
p.line('x', 'Plata', source=source, line_color='yellow', line_width=2, legend_label='Plata')
p.line('x', 'Acero_inoxidable', source=source, line_color='orange', line_width=2, legend_label='Acero_inoxidable')
p.line('x', 'Cobre', source=source, line_color='brown', line_width=2, legend_label='Cobre')



# Añadir una leyenda a la figura
p.legend.location = "top_left"
p.legend.title = 'Líneas'

# Mostrar la figura
show(p)

##Con la siguiente gráfica puedes observar la conductividad de los elementos
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1478">Loading BokehJS ...</span>
#     </div>
# ...
#   <div class="bk-root" id="473e71b6-9664-40df-8687-f77cdfdb96a5" data-root-id="1480"></div>
